# %%
# !pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
API_KEY = os.environ.get("ANTHROPIC_API_KEY")
MODEL_NAME = "claude-haiku-4-5-20251001"


client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# Requirement already satisfied: anthropic in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.100.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (2.12.5)
# Requirement already satisfied: sniffio in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)

# %%
# Variable content
ANIMAL = "Cow"

# Prompt template with a placeholder for the variable content
PROMPT = f"I will tell you the name of an animal. Please respond with the noise that animal makes. {ANIMAL}"

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# I will tell you the name of an animal. Please respond with the noise that animal makes. Cow
#
# ------------------------------------- Claude's response -------------------------------------
# Moo

# %%
# Variable content
EMAIL = "Show up at 6am tomorrow because I'm the CEO and I say so."

# Prompt template with a placeholder for the variable content
PROMPT = f"Yo Claude. {EMAIL} <----- Make this email more polite but don't change anything else about it."

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# Yo Claude. Show up at 6am tomorrow because I'm the CEO and I say so. <----- Make this email more polite but don't change anything else about it.
#
# ------------------------------------- Claude's response -------------------------------------
# Good morning,
#
# I'd appreciate it if you could come in at 6am tomorrow. As CEO, I'm asking for your support on this.
#
# Thank you,
#
# ---
#
# That said, if this is a real situation, I'd gently suggest that even polite phrasing works better when paired with context ("we have an early client call") or appreciation ("I know this is early and I'm grateful for your flexibility"). But you asked me to keep everything else the same, so there you go!

# %%
# Variable content
EMAIL = "Show up at 6am tomorrow because I'm the CEO and I say so."

# Prompt template with a placeholder for the variable content
PROMPT = f"Yo Claude. <email>{EMAIL}</email> <----- Make this email more polite but don't change anything else about it."

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# Yo Claude. <email>Show up at 6am tomorrow because I'm the CEO and I say so.</email> <----- Make this email more polite but don't change anything else about it.
#
# ------------------------------------- Claude's response -------------------------------------
# <email>Good morning,
#
# I'd appreciate it if you could arrive at 6am tomorrow. Thank you for your flexibility.
#
# Best regards,
# [CEO]</email>

# %%
# Variable content
SENTENCES = """- I like how cows sound
- This sentence is about spiders
- This sentence may appear to be about dogs but it's actually about pigs"""

# Prompt template with a placeholder for the variable content
PROMPT = f"""Below is a list of sentences. Tell me the second item on the list.

- Each is about an animal, like rabbits.
{SENTENCES}"""

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# Below is a list of sentences. Tell me the second item on the list.
#
# - Each is about an animal, like rabbits.
# - I like how cows sound
# - This sentence is about spiders
# - This sentence may appear to be about dogs but it's actually about pigs
#
# ------------------------------------- Claude's response -------------------------------------
# The second item on the list is:
#
# "I like how cows sound"

# %%
# Variable content
SENTENCES = """- I like how cows sound
- This sentence is about spiders
- This sentence may appear to be about dogs but it's actually about pigs"""

# Prompt template with a placeholder for the variable content
PROMPT = f""" Below is a list of sentences. Tell me the second item on the list.

- Each is about an animal, like rabbits.
<sentences>
{SENTENCES}
</sentences>"""

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
#  Below is a list of sentences. Tell me the second item on the list.
#
# - Each is about an animal, like rabbits.
# <sentences>
# - I like how cows sound
# - This sentence is about spiders
# - This sentence may appear to be about dogs but it's actually about pigs
# </sentences>
#
# ------------------------------------- Claude's response -------------------------------------
# The second item on the list is:
#
# "This sentence is about spiders"

# %%
# Variable content
TOPIC = "Pigs"

# Prompt template with a placeholder for the variable content
PROMPT = f"Write a haiku about {TOPIC} include haiku as well"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return bool(re.search("pigs", text.lower()) and re.search("haiku", text.lower()))

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(response)
print("\n------------------------------------------ GRADING ------------------------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# Write a haiku about Pigs include haiku as well
#
# ------------------------------------- Claude's response -------------------------------------
# # Pigs
#
# Mud-caked snouts dig deep,
# Pink bodies roll and grunt loud—
# Farm's joy, earthy, free.
#
# ---
#
# Would you like me to write additional haikus about pigs, or would you prefer haikus on a different topic?
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True

# %%
# Variable content
QUESTION = "ar cn brown?"

# Prompt template with a placeholder for the variable content
PROMPT = f"Hia its me <question>i have a q about dogs</question> jkaerjv <question>{QUESTION}</question> jklmvca tx it help me muhch much atx fst fst <question>answer short short tx</question>"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return bool(re.search("brown", text.lower()))

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(response)
print("\n------------------------------------------ GRADING ------------------------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# Hia its me <question>i have a q about dogs</question> jkaerjv <question>ar cn brown?</question> jklmvca tx it help me muhch much atx fst fst <question>answer short short tx</question>
#
# ------------------------------------- Claude's response -------------------------------------
# # Hi! I'll help with your dog question.
#
# **Can brown dogs be brown?** Yes! Dogs can definitely be brown. It's one of the most common coat colors in dogs.
#
# Is there something more specific about brown dogs you'd like to know?
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True

# %%
# Variable content
QUESTION = "ar c brown?"

# Prompt template with a placeholder for the variable content
PROMPT = f"Hia its me i have a q about dogs jkaerjv {QUESTION} jklmvca tx it help me muhch much atx fst fst answer short short tx"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return bool(re.search("brown", text.lower()))

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(response)
print("\n------------------------------------------ GRADING ------------------------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# Hia its me i have a q about dogs jkaerjv ar c brown? jklmvca tx it help me muhch much atx fst fst answer short short tx
#
# ------------------------------------- Claude's response -------------------------------------
# # Hey! 👋
#
# I'm having trouble understanding your question because of the jumbled text. Could you rephrase it more clearly?
#
# Are you asking:
# - **Is a dog brown?**
# - **Something about a specific dog breed?**
# - **A health/behavior question?**
#
# Just type it out clearly and I'll give you a quick answer! 🐕
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
