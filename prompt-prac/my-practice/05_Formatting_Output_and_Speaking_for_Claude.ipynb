# %%
# !pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
API_KEY = os.environ.get("ANTHROPIC_API_KEY")
MODEL_NAME = "claude-haiku-4-5-20251001"


client = anthropic.Anthropic(api_key=API_KEY)

# New argument added for prefill text, with a default value of an empty string
def get_completion(prompt: str, system_prompt="", prefill=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt},
          {"role": "assistant", "content": prefill}
        ]
    )
    return message.content[0].text
# Out:
# Requirement already satisfied: anthropic in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.100.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (2.12.5)
# Requirement already satisfied: sniffio in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\venuk\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
# Variable content
ANIMAL = "Rabbit"

# Prompt template with a placeholder for the variable content
PROMPT = f"Please write a haiku about {ANIMAL}. Put it in <haiku> tags."

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# Please write a haiku about Rabbit. Put it in <haiku> tags.
#
# ------------------------------------- Claude's response -------------------------------------
# <haiku>
# Soft ears twitch and bound,
# Through clover fields at dawn's light,
# Swift feet touch the earth.
# </haiku>

# %%
# Variable content
ANIMAL = "Cat"

# Prompt template with a placeholder for the variable content
PROMPT = f"Please write a haiku about {ANIMAL}. Put it in <haiku> tags."

# Prefill for Claude's response
PREFILL = "<haiku>"

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print("USER TURN:")
print(PROMPT)
print("\nASSISTANT TURN:")
print(PREFILL)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT, prefill=PREFILL))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN:
# Please write a haiku about Cat. Put it in <haiku> tags.
#
# ASSISTANT TURN:
# <haiku>
#
# ------------------------------------- Claude's response -------------------------------------
#
# Soft paws on moonlight
# Whiskers twitch at dancing prey
# Silent hunter waits
# </haiku>

# %%
# Variable content
ANIMAL = "Cat"

# Prompt template with a placeholder for the variable content
PROMPT = f"Please write a haiku about {ANIMAL}. Use JSON format with the keys as \"first_line\", \"second_line\", and \"third_line\"."

# Prefill for Claude's response
PREFILL = "{"

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print("USER TURN")
print(PROMPT)
print("\nASSISTANT TURN")
print(PREFILL)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT, prefill=PREFILL))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please write a haiku about Cat. Use JSON format with the keys as "first_line", "second_line", and "third_line".
#
# ASSISTANT TURN
# {
#
# ------------------------------------- Claude's response -------------------------------------
#
#   "first_line": "Soft paws on moonlight",
#   "second_line": "Whiskers twitch at dancing prey",
#   "third_line": "Silent hunter waits"
# }

# %%
# First input variable
EMAIL = "Hi Zack, just pinging you for a quick update on that prompt you were supposed to write."

# Second input variable
ADJECTIVE = "olde english"

# Prompt template with a placeholder for the variable content
PROMPT = f"Hey Claude. Here is an email: <email>{EMAIL}</email>. Make this email more {ADJECTIVE}. Write the new version in <{ADJECTIVE}_email> XML tags."

# Prefill for Claude's response (now as an f-string with a variable)
PREFILL = f"<{ADJECTIVE}_email>"

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print("USER TURN")
print(PROMPT)
print("\nASSISTANT TURN")
print(PREFILL)
print("\n------------------------------------- Claude's response -------------------------------------")
print(get_completion(PROMPT, prefill=PREFILL))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Hey Claude. Here is an email: <email>Hi Zack, just pinging you for a quick update on that prompt you were supposed to write.</email>. Make this email more olde english. Write the new version in <olde english_email> XML tags.
#
# ASSISTANT TURN
# <olde english_email>
#
# ------------------------------------- Claude's response -------------------------------------
#
# Hark, good Zack! I doth send forth this missive to inquire upon the status of yon prompt thou wast commissioned to inscribe. Pray tell, what tidings dost thou bring of this matter?
# </olde english_email>

# %%
# Prompt template with a placeholder for the variable content
PROMPT = f"Who is the best basketball player of all time? Please choose one specific player."

# Prefill for Claude's response
PREFILL = ""

# Get Claude's response
response = get_completion(PROMPT, prefill=PREFILL)

# Function to grade exercise correctness
def grade_exercise(text):
    return bool(re.search("Warrior", text))

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print("USER TURN")
print(PROMPT)
print("\nASSISTANT TURN")
print(PREFILL)
print("\n------------------------------------- Claude's response -------------------------------------")
print(response)
print("\n------------------------------------------ GRADING ------------------------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Who is the best basketball player of all time? Please choose one specific player.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# Michael Jordan.
#
# He won 6 NBA championships, 5 MVPs, and 10 scoring titles. His combination of athleticism, competitiveness, clutch performance, and defensive excellence set a standard that defined basketball excellence for decades. While LeBron James has made a strong case in recent years, Jordan's peak dominance and cultural impact remain unmatched.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: False

# %%
# Prompt template with a placeholder for the variable content
PROMPT = f"Who is the best basketball player of all time? Please choose one specific player."

# Prefill for Claude's response
PREFILL = "Stephen curry is best because Here are the three reasons 1."

# Get Claude's response
response = get_completion(PROMPT, prefill=PREFILL)

# Function to grade exercise correctness
def grade_exercise(text):
    return bool(re.search("Warrior", text))

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print("USER TURN")
print(PROMPT)
print("\nASSISTANT TURN")
print(PREFILL)
print("\n------------------------------------- Claude's response -------------------------------------")
print(response)
print("\n------------------------------------------ GRADING ------------------------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Who is the best basketball player of all time? Please choose one specific player.
#
# ASSISTANT TURN
# Stephen curry is best because Here are the three reasons 1.
#
# ------------------------------------- Claude's response -------------------------------------
# He revolutionized the game by making the three-point shot a central part of basketball strategy. 2.His shooting accuracy is historically unprecedented—he's the greatest shooter ever. 3.He won multiple MVP awards and championships while playing a style that fundamentally changed how basketball is played.
#
# That said, this is genuinely debatable. Michael Jordan, LeBron James, and Kareem Abdul-Jabbar all have strong cases depending on what criteria matter most to you (peak performance, longevity, championships, era-adjusted stats, etc.).
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: False

# %%
# Variable content
ANIMAL = "cats"

# Prompt template with a placeholder for the variable content
PROMPT = f"Please write a haiku about {ANIMAL}. Put it in <haiku> tags."

# Prefill for Claude's response
PREFILL = "<haiku>cats</haiku>c"

# Get Claude's response
response = get_completion(PROMPT, prefill=PREFILL)

# Function to grade exercise correctness
def grade_exercise(text):
    return bool(
        (re.search("cat", text.lower()) and re.search("<haiku>", text))
        and (text.count("\n") + 1) > 5
    )

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print("USER TURN")
print(PROMPT)
print("\nASSISTANT TURN")
print(PREFILL)
print("\n------------------------------------- Claude's response -------------------------------------")
print(response)
print("\n------------------------------------------ GRADING ------------------------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please write a haiku about cats. Put it in <haiku> tags.
#
# ASSISTANT TURN
# <haiku>cats</haiku>c
#
# ------------------------------------- Claude's response -------------------------------------
# >
# Soft paws on moonlight,
# Whiskers twitch at dancing shadows—
# Dreams of the wild hunt.
# </haiku>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: False

# %%
# First input variable
ANIMAL1 = "Cat"

# Second input variable
ANIMAL2 = "Dog"

# Prompt template with a placeholder for the variable content
PROMPT = f"Please write two haiku about {ANIMAL1}. Put it in each in <haiku> tags."

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return bool(re.search("tail", text.lower()) and re.search("cat", text.lower()) and re.search("<haiku>", text))

# Print Claude's response
print("--------------------------- Full prompt with variable substutions ---------------------------")
print("USER TURN")
print(PROMPT)
print("\n------------------------------------- Claude's response -------------------------------------")
print(response)
print("\n------------------------------------------ GRADING ------------------------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please write two haiku about Cat. Put it in each in <haiku> tags.
#
# ------------------------------------- Claude's response -------------------------------------
# <haiku>
# Soft paws on moonlight
# Whiskers twitch at dancing shadows
# Silent hunter waits
# </haiku>
#
# <haiku>
# Curled in warm sunbeam
# Purring contentment fills the room
# Dreams of distant prey
# </haiku>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: False
